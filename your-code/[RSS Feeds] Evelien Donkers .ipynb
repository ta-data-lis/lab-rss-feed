# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser
import pandas as pd
import re
from collections import Counter

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
feeds = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
feeds
# Out:
# {'feed': {'title': 'Radar',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Radar'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.oreilly.com/radar'},
#    {'rel': 'self',
#     'type': 'application/rss+xml',
#     'href': 'http://feeds.feedburner.com/oreilly/radar/atom'},
#    {'rel': 'hub',
#     'href': 'http://pubsubhubbub.appspot.com/',
#     'type': 'text/html'}],
#   'link': 'https://www.oreilly.com/radar',
#   'subtitle': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology'},
#   'updated': 'Tue, 05 Nov 2019 12:28:35 +0000',
#   'updated_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=5, tm_hour=12, tm_min=28, tm_sec=35, tm_wday=1, tm_yday=309, tm_isdst=0),
#   'language': 'en-US',
#   'sy_updateperiod': 'hourly',
#   'sy_updatefrequency': '1',
#   'generator_detail': {'name': 'https://wordpress.org/?v=5.2.4'},
#   'generator': 'https://wordpress.org/?v=5.2.4',
#   'feedburner_info': {'uri': 'oreilly/radar/atom'},
#   'geo_lat': '38.393314',
#   'geo_long': '-122.836667',
#   'feedburner_emailserviceid': 'oreilly/radar/atom',
#   'feedburner_feedburnerhostname': 'https://feedburner.google.com'},
#  'entries': [{'title': 'Four short links: 6 November 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 6 November 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HApLcqKbwf8/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HApLcqKbwf8/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-6-november-2019/#respond',
#    'published': 'Wed, 06 Nov 2019 05:01:31 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=6, tm_hour=5, tm_min=1, tm_sec=31, tm_wday=2, tm_yday=310, tm_isdst=0),
#    'authors': [{'name': 'Nat Torkington'}],
#    'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10648',
#    'guidislink': False,
#    'summary': 'Things I Wish Someone Had Explained About Functional Programming (James Sinclair) &#8212; But it&#8217;s not long before things get complicated. We start with a bunch of simple functions. Easy. But the types don’t all line up. And we need to generate some side effects, too. And handle errors. And manage state. And how do you [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Things I Wish Someone Had Explained About Functional Programming (James Sinclair) &#8212; But it&#8217;s not long before things get complicated. We start with a bunch of simple functions. Easy. But the types don’t all line up. And we need to generate some side effects, too. And handle errors. And manage state. And how do you [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol><li><a href="https://jrsinclair.com/articles/2019/what-i-wish-someone-had-explained-about-functional-programming/">Things I Wish Someone Had Explained About Functional Programming</a> (James Sinclair) &#8212; <em>But it&#8217;s not long before things get complicated. We start with a bunch of simple functions. Easy. But the types don’t all line up. And we need to generate some side effects, too. And handle errors. And manage state. And how do you debug this? It gets tricky, quick. Functional programming has idioms and tools to solve all these challenges. But learning them is hard if nobody shows you where to look.</em></li><li><a href="https://scholar.harvard.edu/files/helpman/files/fakenews091819_combined.pdf">Electoral Competition with Fake News</a> &#8212; <em>We introduce opportunities for political candidates and their media supporters to spread fake news about the policy environment and perhaps about parties&#8217; positions into a familiar model of electoral competition. In the baseline model with full information, the parties&#8217; positions converge to those that maximize aggregate welfare. When parties can broadcast fake news to audiences that disproportionately include their partisans, policy divergence and suboptimal outcomes can result. We study a sequence of models that impose progressively tighter constraints on false reporting and characterize situations that lead to divergence and a polarized electorate.</em></li><li><a href="https://research.fb.com/publications/live-face-de-identification-in-video/">Live Face De-Identification in Video</a> &#8212; <em>We propose a method for face de-identification that enables fully automatic video modification at high frame rates. The goal is to maximally decorrelate the identity, while having the perception (pose, illumination, and expression) fixed. We achieve this by a novel feed-forward encoder-decoder network architecture that is conditioned on the high-level representation of a person’s facial image. The network is global, in the sense that it does not need to be retrained for a given video or for a given identity, and it creates natural looking image sequences with little distortion in time.</em></li><li><a href="https://www.youtube.com/watch?v=Re1MAO6jOLE">Lessons Learned from Sendmail</a> (Eric Allman) &#8212; Sendmail has a bad rap with the kids, but it&#8217;s worth listening to how it came about. If you ever invent something that has the market share that Sendmail had, then you&#8217;ll have regrets, too. This is a good opportunity to learn from Eric&#8217;s.</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/HApLcqKbwf8" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-6-november-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-6-november-2019/'},
#   {'title': 'It’s important to cultivate your organization’s collective genius',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'It’s important to cultivate your organization’s collective genius'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/wn75FBxJkk8/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/wn75FBxJkk8/',
#    'comments': 'https://www.oreilly.com/radar/its-important-to-cultivate-your-organizations-collective-genius/#respond',
#    'published': 'Tue, 05 Nov 2019 05:05:36 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=5, tm_hour=5, tm_min=5, tm_sec=36, tm_wday=1, tm_yday=309, tm_isdst=0),
#    'authors': [{'name': 'Jenn Webb'}],
#    'author': 'Jenn Webb',
#    'author_detail': {'name': 'Jenn Webb'},
#    'tags': [{'term': 'Future of the Firm', 'scheme': None, 'label': None},
#     {'term': 'Deep Dive', 'scheme': None, 'label': None},
#     {'term': "Foo Camp '19", 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10231',
#    'guidislink': False,
#    'summary': 'In this interview from O&#8217;Reilly Foo Camp 2019, Pamela Rucker, president of The Rucker Group, discusses the challenges people face when they&#8217;re entering into management roles for the first time, and how CxOs can help mitigate some of those challenges. She also talks about the future of work and how nurturing talent is going to [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'In this interview from O&#8217;Reilly Foo Camp 2019, Pamela Rucker, president of The Rucker Group, discusses the challenges people face when they&#8217;re entering into management roles for the first time, and how CxOs can help mitigate some of those challenges. She also talks about the future of work and how nurturing talent is going to [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>In this interview from O&#8217;Reilly Foo Camp 2019, Pamela Rucker, president of The Rucker Group, discusses the challenges people face when they&#8217;re entering into management roles for the first time, and how CxOs can help mitigate some of those challenges. She also talks about the future of work and how nurturing talent is going to be more important than ever.</p>\n\n\n\n<p>Highlights from the interview include:</p>\n\n\n\n<p>One of the biggest challenges new managers face is asking for help or clarification during the transition to their new management role. Rucker says the issue has more to do with company culture and leadership than with shy managers. &#8220;There are some organizations where even the most expressive people have difficulty speaking up because the culture is such that you don&#8217;t go against the grain. You don&#8217;t say anything. I remember working at a large legacy organization and we had done a great job setting the tone in the room, talking about all the things that people need to work on, how they need to be able to express their challenges, and maybe where they don&#8217;t get it. So I said, &#8216;Tell me some of the things you&#8217;re concerned about right now.&#8217; I saw on the people&#8217;s faces that they were ready to speak, and the C-level executives chose that moment to step up and say, &#8216;I really wonder who&#8217;s going to say anything.&#8217; Instantly, everyone shut down. So, I do think it&#8217;s situational. There are times when you might have people who would be brave enough to say something, but the leader has the responsibility to enable the voice. The leader has a responsibility to let people have enough power to say something in that moment that maybe they don&#8217;t agree with, and to recognize that it&#8217;s not saying anything about them as an individual leader as much as it is about the person who might need help walking that bridge.&#8221; (<a href="#t=160">02:40</a>)</p>\n\n\n\n<p>Rucker also discusses the concept of &#8220;dual paths&#8221;—not everyone is cut out to be a manager; there are other paths to fulfilling career goals, and to rewarding outstanding work. &#8220;If you think about how people transition and become more valuable over time to organizations, typically, there&#8217;s this belief that the only way for me to show additional value is for me to become a manager. &#8230; There&#8217;s an opportunity not just to progress as a manager, but maybe to go deep in your expertise, and then demonstrate how you might be well-connected in the organization or well-connected in the industry, and show how that adds value to the company&#8217;s strategic priorities. That&#8217;s just as important as being able to manage people. Talking to an organization about how they can create those types of roles is important as well because it shouldn&#8217;t be that the only way you can achieve the things you want to achieve in life is to be forced into the ability to manage people or manage projects, which may not align with your capabilities.&#8221; (<a href="#t=348">05:48</a>)</p>\n\n\n\n<p>The future of work is going to raise more issues than navigating remote work or gig economies—Rucker says leaders will need a vastly different skill set. &#8220;It&#8217;s not just about technology, but also about how to look at your staff and figure out what their capabilities are and then figure out how to attach that to your capability and really use the power of collective genius. Your competitive advantage is going to come from what you know about your customers, what you know about the products and services you offer, and what you know about your people, and then how you put those things together to come up with an incredible recipe that cannot be duplicated because you have talent equity. &#8230; A leader will need to foster an environment where they all can come together and raise up those hidden talents and then collectively put them together into so ...
#    'wfw_commentrss': 'https://www.oreilly.com/radar/its-important-to-cultivate-your-organizations-collective-genius/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/its-important-to-cultivate-your-organizations-collective-genius/'},
#   {'title': 'Four short links: 5 November 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 5 November 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Thacsx74uOM/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Thacsx74uOM/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-5-november-2019/#respond',
#    'published': 'Tue, 05 Nov 2019 05:01:13 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=5, tm_hour=5, tm_min=1, tm_sec=13, tm_wday=1, tm_yday=309, tm_isdst=0),
#    'authors': [{'name': 'Nat Torkington'}],
#    'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10644',
#    'guidislink': False,
#    'summary': '&#8220;Nearly All&#8221; Counter-Strike Microtransactions Are Being Used for Money Laundering (Vice) &#8212; I&#8217;ve been chewing on this all week. There are a lot of unmet desires in the world, desires that are unmet because society makes them illegal to meet. If your service can be adapted to meet these desires, then it will be. And [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '&#8220;Nearly All&#8221; Counter-Strike Microtransactions Are Being Used for Money Laundering (Vice) &#8212; I&#8217;ve been chewing on this all week. There are a lot of unmet desires in the world, desires that are unmet because society makes them illegal to meet. If your service can be adapted to meet these desires, then it will be. And [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol><li><a href="https://www.vice.com/en_us/article/8xw7nx/nearly-all-counter-strike-microtransactions-are-being-used-for-money-laundering">&#8220;Nearly All&#8221; Counter-Strike Microtransactions Are Being Used for Money Laundering</a> (Vice) &#8212; I&#8217;ve been chewing on this all week. There are a lot of unmet desires in the world, desires that are unmet because society makes them illegal to meet. If your service can be adapted to meet these desires, then it will be. And you&#8217;ll have a problem.</li><li><a href="https://www.whonix.org/">Whonix</a> &#8212; <em>a desktop operating system designed for advanced security and privacy. Whonix mitigates the threat of common attack vectors while maintaining usability. Online anonymity is realized via fail-safe, automatic, and desktop-wide use of the Tor network. A heavily reconfigured Debian base is run inside multiple virtual machines, providing a substantial layer of protection from malware and IP address leaks. Commonly used applications are pre-installed and safely pre-configured for immediate use. The user is not jeopardized by installing additional applications or personalizing the desktop. Whonix is under active development and is the only operating system designed to be run inside a VM and paired with Tor.</em></li><li><a href="https://ruthmalan.com/Journal/2019/20190629SlideDocTechnicalLeadershipDecisions.pdf">Technical Leadership Masterclass: Decisions</a> (Ruth Malan) &#8212; a deep dive into different frameworks and considerations when making decisions.</li><li><a href="https://twilio-labs.github.io/socless/">SOCless: Automated Security Playbooks</a> &#8212; Twilio&#8217;s open source serverless framework to execute user-defined workflows in response to alerts or scheduled events.</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/Thacsx74uOM" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-5-november-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-5-november-2019/'},
#   {'title': 'Four short links: 4 November 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 4 November 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/JNSNstQo6Cw/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/JNSNstQo6Cw/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-4-november-2019/#respond',
#    'published': 'Mon, 04 Nov 2019 05:01:01 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=4, tm_hour=5, tm_min=1, tm_sec=1, tm_wday=0, tm_yday=308, tm_isdst=0),
#    'authors': [{'name': 'Nat Torkington'}],
#    'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10612',
#    'guidislink': False,
#    'summary': 'Beyond Bots and Trolls: Understanding Disinformation as Collaborative Work &#8212; we examine three case studies of online information operations using a sociotechnical lens that draws on CSCW theories and methods to account for the mutual shaping of technology, social structure, and human action. Through this lens, we contribute a more nuanced understanding of these operations [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Beyond Bots and Trolls: Understanding Disinformation as Collaborative Work &#8212; we examine three case studies of online information operations using a sociotechnical lens that draws on CSCW theories and methods to account for the mutual shaping of technology, social structure, and human action. Through this lens, we contribute a more nuanced understanding of these operations [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol><li><a href="http://faculty.washington.edu/kstarbi/StarbirdArifWilson_DisinformationasCollaborativeWork-CameraReady-Preprint.pdf">Beyond Bots and Trolls: Understanding Disinformation as Collaborative Work</a> &#8212; <em>we examine three case studies of online information operations using a sociotechnical lens that draws on CSCW theories and methods to account for the mutual shaping of technology, social structure, and human action. Through this lens, we contribute a more nuanced understanding of these operations (beyond “bots” and “trolls”) and highlight a persistent challenge for researchers, platform designers, and policy makers—distinguishing between orchestrated, explicitly coordinated, information operations and the emergent, organic behaviors of an online crowd.</em></li><li><a href="https://alf.io/">Alf.io</a> &#8212; open source ticket reservation system. Their <a href="https://alfio.netlify.com/">draft new web site</a> does a better job explaining what they do and why they&#8217;re good. (via <a href="https://news.ycombinator.com/item?id=21411267">Hacker News</a>)</li><li><a href="https://meatspacepress.com/">How to Run a City Like Amazon, and Other Fables</a> &#8212; <em>The idea behind the book is to ask what would it be like to live in a city administered using the business model of Amazon (or Apple, IKEA, Pornhub, Spotify, Tinder, Uber, and more), or a city where critical public services are delivered by these companies?</em> (via <a href="https://twitter.com/RobKitchin/status/1188783861993562113">Rob Kitchin</a>)</li><li><a href="https://quiet.github.io/quiet-js/">Quiet.js</a> &#8212; <em>a javascript binding for libquiet, a library for sending and receiving data via sound card. It can function either via speaker or cable (e.g., 3.5mm). Quiet comes included with a few transmissions profiles which can be selected for the intended use. For speaker transmission, there is a profile which transmits around the 19kHz range, which is essentially imperceptible to the human ear. Quiet uses the Web Audio functionality in order to send and receive sound. Sending data is supported by Chrome, Firefox, Safari, and Edge. Reception is supported by Chrome, Edge, and to some extent Firefox.</em></li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/JNSNstQo6Cw" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-4-november-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-4-november-2019/'},
#   {'title': 'Quantum computing’s potential is still far off, but quantum supremacy shows we’re on the right track',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Quantum computing’s potential is still far off, but quantum supremacy shows we’re on the right track'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9Fuea1TTT4E/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9Fuea1TTT4E/',
#    'comments': 'https://www.oreilly.com/radar/quantum-computings-potential-is-still-far-off-but-quantum-supremacy-shows-were-on-the-right-track/#respond',
#    'published': 'Fri, 01 Nov 2019 04:05:34 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=4, tm_min=5, tm_sec=34, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Mike Loukides'}],
#    'author': 'Mike Loukides',
#    'author_detail': {'name': 'Mike Loukides'},
#    'tags': [{'term': 'Innovation & Disruption', 'scheme': None, 'label': None},
#     {'term': 'Radar Column', 'scheme': None, 'label': None},
#     {'term': 'Commentary', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10154',
#    'guidislink': False,
#    'summary': 'One of the most exciting topics we’ve been following is the development of quantum computing. We recently learned about a major breakthrough: Google says it has achieved “quantum supremacy” with a 53-qubit computer. I will steer clear of a lengthy explanation of quantum computing, which I’m not really competent to give. Quantum supremacy itself is [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'One of the most exciting topics we’ve been following is the development of quantum computing. We recently learned about a major breakthrough: Google says it has achieved “quantum supremacy” with a 53-qubit computer. I will steer clear of a lengthy explanation of quantum computing, which I’m not really competent to give. Quantum supremacy itself is [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>One of the most exciting topics we’ve been following is the development of quantum computing. We recently learned about a major breakthrough: <a href="https://www.nature.com/articles/s41586-019-1666-5">Google says it has achieved “quantum supremacy”</a> with a 53-qubit computer.</p>\n<p>I will steer clear of a lengthy explanation of quantum computing, which I’m not really competent to give. Quantum supremacy itself is a simple concept: it means performing a computation that could not be performed on a classical computer.</p>\n<p>It’s very important to understand exactly what this means. Google performed a computation in a few minutes (3 minutes, 20 seconds to be <a href="https://www.nytimes.com/2019/10/23/technology/quantum-computing-google.html">precise</a>) that would have taken more than 10,000 years on the most powerful computers we currently have. But that’s a speedup for one specific computation, and that computation has no practical value. (<a href="https://medium.com/starts-with-a-bang/has-google-actually-achieved-quantum-supremacy-with-its-new-quantum-computer-b59d051f3d88">This explanation of the computation</a> is the best I’ve seen.) Google has verified that the result is correct—a statistical distribution that is subtly different from a Gaussian distribution.</p>\n<p>This is a major breakthrough, despite <a href="https://www.ibm.com/blogs/research/2019/10/on-quantum-supremacy/">some controversy</a> (though it’s worth pointing out that researchers <a href="https://www.quantamagazine.org/john-preskill-explains-quantum-supremacy-20191002/">John Preskill</a>—who coined the term “quantum supremacy”—and <a href="https://www.scottaaronson.com/blog/?p=4372">Scott Aaronson</a> accept Google’s understanding of quantum supremacy).</p>\n<p>It’s important to consider what this achievement does <em>not</em> mean. It does not mean that cryptography is broken, or that we can achieve general artificial intelligence, or anything of the sort. Remember, this result is about one specific computation with no practical value; it’s meaningless, except perhaps as a random number generator that obeys an odd distribution. To break current cryptographic techniques, we’ll need quantum computers with thousands of qubits. And qubits don’t stack up as easily as bytes in a memory chip.</p>\n<p>One fundamental problem with quantum computers is that the probability they’ll return an incorrect answer is always non-zero. To do meaningful computation on a quantum computer, we’ll need to develop quantum error correction. Error correction is well understood for classical computers; error correction for quantum computers isn’t. One error-corrected qubit (a “logical” qubit) may require more than a thousand physical qubits. So breaking cryptography, which may require thousands of logical qubits, will require <a href="https://www.scottaaronson.com/blog/?p=4317">millions of physical qubits</a>. Quantum computers of that scale are still a long way off.</p>\n<p>Quantum supremacy, now and in some imagined future, also doesn’t mean that digital computers become obsolete. Most of what we do on our computers—fancy graphics, email, databases, building websites, data analysis, digital signal processing—can’t be done with quantum computing. Certainly not now, and possibly never. Quantum computing is useful to speed up a relatively small number of very difficult computational problems that can’t be solved on classical computers. I suspect that quantum computers won’t be computers as such (certainly not laptops, unless you can manage a laptop that runs at temperatures close to absolute zero); they’ll be more like GPUs, specialized attachments that run certain kinds of computations.</p>\n<p>I also suspect that, for quantum computers, Thomas J. Watson’s notorious (and perhaps <a href="https://en.wikipedia.org/wiki/Thomas_J._Watson#Famous_attribution">apocryphal</a>) prediction that the total market for computers would be five, might be close to the trut ...
#    'wfw_commentrss': 'https://www.oreilly.com/radar/quantum-computings-potential-is-still-far-off-but-quantum-supremacy-shows-were-on-the-right-track/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/quantum-computings-potential-is-still-far-off-but-quantum-supremacy-shows-were-on-the-right-track/'},
#   {'title': 'Four short links: 1 November 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 1 November 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/oInoNMRLUXw/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/oInoNMRLUXw/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-1-november-2019/#respond',
#    'published': 'Fri, 01 Nov 2019 04:01:53 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=4, tm_min=1, tm_sec=53, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Nat Torkington'}],
#    'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10586',
#    'guidislink': False,
#    'summary': 'Vortimo &#8212; software that organizes information on webpages you’ve visited. It records pages you go to, extracts data from them, and enriches the data that was extracted. It augments the pages in your browser by allowing you to tag objects as well as decorating objects it deems important. It then arranges the data in a [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Vortimo &#8212; software that organizes information on webpages you’ve visited. It records pages you go to, extracts data from them, and enriches the data that was extracted. It augments the pages in your browser by allowing you to tag objects as well as decorating objects it deems important. It then arranges the data in a [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol><li><a href="http://vortimo.com/beta3/">Vortimo</a> &#8212; <em>software that organizes information on webpages you’ve visited. It records pages you go to, extracts data from them, and enriches the data that was extracted. It augments the pages in your browser by allowing you to tag objects as well as decorating objects it deems important. It then arranges the data in a UI. Vortimo supports switching between cases/projects seamlessly. You can also generate PDF reports based on the aggregated information and meta information.</em></li><li><a href="http://deeppavlov.ai/">DeepPavlov</a> &#8212; <em>An open source conversational AI framework</em>.</li><li><a href="https://papers.ssrn.com/sol3/papers.cfm?abstract_id=998565">&#8216;I&#8217;ve Got Nothing to Hide&#8217; and Other Misunderstandings of Privacy</a> &#8212; 2007 paper <em>In this essay, I will explore the &#8220;nothing to hide&#8221; argument and its variants in more depth. Grappling with the &#8220;nothing to hide&#8221; argument is important because the argument reflects the sentiments of a wide percentage of the population. In popular discourse, the &#8220;nothing to hide&#8221; argument’s superficial incantations can readily be refuted. But when the argument is made in its strongest form, it is far more formidable.</em></li><li><a href="https://www.minersoc.org/wp-content/uploads/2019/05/3ICM-Michaux.pdf">Projected Battery Minerals and Metals Global Shortage</a> &#8212; eye-watering presentation, estimating the effect of predicted demand upon the supply/availability of key minerals and metals. Contains alarming statements like: <em>What is needed to replace 2016 global fleet would consume 93.3% of Global Ni Resources</em>.</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/oInoNMRLUXw" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-1-november-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-1-november-2019/'},
#   {'title': 'Highlights from TensorFlow World in Santa Clara, California 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Highlights from TensorFlow World in Santa Clara, California 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/DM72RqFb2G4/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/DM72RqFb2G4/',
#    'comments': 'https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019/#respond',
#    'published': 'Fri, 01 Nov 2019 00:30:39 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=30, tm_sec=39, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Mac Slocum'}],
#    'author': 'Mac Slocum',
#    'author_detail': {'name': 'Mac Slocum'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10168',
#    'guidislink': False,
#    'summary': 'People from across the TensorFlow community came together in Santa Clara, California for TensorFlow World. Below you&#8217;ll find links to highlights from the event. Opening keynote Jeff Dean explains why Google open-sourced TensorFlow and discusses its progress. Watch &#8220;Opening keynote&#8220; Accelerating ML at Twitter Theodore Summe offers a glimpse into how Twitter employs machine learning [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'People from across the TensorFlow community came together in Santa Clara, California for TensorFlow World. Below you&#8217;ll find links to highlights from the event. Opening keynote Jeff Dean explains why Google open-sourced TensorFlow and discusses its progress. Watch &#8220;Opening keynote&#8220; Accelerating ML at Twitter Theodore Summe offers a glimpse into how Twitter employs machine learning [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>People from across the TensorFlow community came together in Santa Clara, California for <a href="https://conferences.oreilly.com/tensorflow/tf-ca">TensorFlow World</a>. Below you&#8217;ll find links to highlights from the event.</p>\n<h2>Opening keynote</h2>\n<p>Jeff Dean explains why Google open-sourced TensorFlow and discusses its progress.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tensorflow-world-2019-opening-keynote">Opening keynote</a>&#8220;</li>\n</ul>\n<h2>Accelerating ML at Twitter</h2>\n<p>Theodore Summe offers a glimpse into how Twitter employs machine learning throughout its product.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/accelerating-ml-at-twitter">Accelerating ML at Twitter</a>&#8220;</li>\n</ul>\n<h2>The latest from TensorFlow</h2>\n<p>Megan Kacholia explains how Google’s latest innovations provide an ecosystem of tools for developers, enterprises, and researchers who want to build scalable ML-powered applications.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-latest-from-tensorflow">The latest from TensorFlow</a>&#8220;</li>\n</ul>\n<h2>TensorFlow community announcements</h2>\n<p>Kemal El Moujahid reveals new developments for the TensorFlow community.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tensorflow-community-announcements">TensorFlow community announcements</a>&#8220;</li>\n</ul>\n<h2>TFX: An end-to-end ML platform for everyone</h2>\n<p>Konstantinos Katsiapis and Anusha Ramesh dive into the insights and approach that helped TensorFlow Extended (TFX) reach its current popularity within Alphabet.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tfx-an-end-to-end-ml-platform-for-everyone">TFX: An end-to-end ML platform for everyone</a>&#8220;</li>\n</ul>\n<h2>Personalization of Spotify Home and TensorFlow</h2>\n<p>Tony Jebara explains how Spotify improved user satisfaction by building components of the TFX ecosystem into its core ML infrastructure.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/personalization-of-spotify-home-and-tensorflow">Personalization of Spotify Home and TensorFlow</a>&#8220;</li>\n</ul>\n<h2>TensorFlow Hub: The platform to share and discover pretrained models for TensorFlow</h2>\n<p>Mike Liang discusses TensorFlow Hub, a platform where developers can share and discover pretrained models and benefit from transfer learning.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tensorflow-hub-the-platform-to-share-and-discover-pretrained-models-for-tensorflow">TensorFlow Hub: The platform to share and discover pretrained models for TensorFlow</a>&#8220;</li>\n</ul>\n<h2>“Human error”: How can we help people build models that do what they expect</h2>\n<p>Anna Roth discusses human and technical factors and suggests future directions for training machine learning models.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/human-error-how-can-we-help-people-build-models-that-do-what-they-expect">“Human error”: How can we help people build models that do what they expect</a>&#8220;</li>\n</ul>\n<h2>TensorFlow Lite: ML for mobile and IoT devices</h2>\n<p>Jared Duke and Sarah Sirajuddin explore on-device machine learning and the latest updates to TensorFlow Lite.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tensorflow-lite-ml-for-mobile-and-iot-devices">TensorFlow Lite: ML for mobile and IoT devices</a>&#8220;</li>\n</ul>\n<h2>Sticker recommendations and AI-driven innovations on the Hike messaging platform</h2>\n<p>Ankur Narang discusses sticker recommendations with multilingual support, a key innovation driven by sophisticated natural language processing (NLP) algorithms.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/sticker-recommendations-and-ai-driven-innovations-on-the-hike-messaging-platform">Sticker recommendations and AI-driven innovations on the Hike messagin ...
#    'wfw_commentrss': 'https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019/'},
#   {'title': 'Sticker recommendations and AI-driven innovations on the Hike messaging platform',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Sticker recommendations and AI-driven innovations on the Hike messaging platform'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/jZNzhYYiqV4/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/jZNzhYYiqV4/',
#    'comments': 'https://www.oreilly.com/radar/sticker-recommendations-and-ai-driven-innovations-on-the-hike-messaging-platform/#respond',
#    'published': 'Fri, 01 Nov 2019 00:00:59 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=59, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Ankur Narang'}],
#    'author': 'Ankur Narang',
#    'author_detail': {'name': 'Ankur Narang'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10426',
#    'guidislink': False,
#    'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/jZNzhYYiqV4" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/sticker-recommendations-and-ai-driven-innovations-on-the-hike-messaging-platform/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/sticker-recommendations-and-ai-driven-innovations-on-the-hike-messaging-platform/'},
#   {'title': '“Human error”: How can we help people build models that do what they expect',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '“Human error”: How can we help people build models that do what they expect'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/IN5fi_-N3Ic/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/IN5fi_-N3Ic/',
#    'comments': 'https://www.oreilly.com/radar/human-error-how-can-we-help-people-build-models-that-do-what-they-expect/#respond',
#    'published': 'Fri, 01 Nov 2019 00:00:58 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=58, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Anna Roth'}],
#    'author': 'Anna Roth',
#    'author_detail': {'name': 'Anna Roth'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10414',
#    'guidislink': False,
#    'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/IN5fi_-N3Ic" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/human-error-how-can-we-help-people-build-models-that-do-what-they-expect/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/human-error-how-can-we-help-people-build-models-that-do-what-they-expect/'},
#   {'title': 'Personalization of Spotify Home and TensorFlow',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Personalization of Spotify Home and TensorFlow'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/4SDP5ZmXUA4/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/4SDP5ZmXUA4/',
#    'comments': 'https://www.oreilly.com/radar/personalization-of-spotify-home-and-tensorflow/#respond',
#    'published': 'Fri, 01 Nov 2019 00:00:46 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=46, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Tony Jebara'}],
#    'author': 'Tony Jebara',
#    'author_detail': {'name': 'Tony Jebara'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10400',
#    'guidislink': False,
#    'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/4SDP5ZmXUA4" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/personalization-of-spotify-home-and-tensorflow/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/personalization-of-spotify-home-and-tensorflow/'},
#   {'title': 'TensorFlow.js: Bringing machine learning to JavaScript',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'TensorFlow.js: Bringing machine learning to JavaScript'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/kFj_13YToRg/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/kFj_13YToRg/',
#    'comments': 'https://www.oreilly.com/radar/tensorflow-js-bringing-machine-learning-to-javascript/#respond',
#    'published': 'Fri, 01 Nov 2019 00:00:36 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=36, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Sandeep Gupta and Joseph Paul Cohen'}],
#    'author': 'Sandeep Gupta and Joseph Paul Cohen',
#    'author_detail': {'name': 'Sandeep Gupta and Joseph Paul Cohen'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10436',
#    'guidislink': False,
#    'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/kFj_13YToRg" height="1" width="1" alt=""/>'}],
# ...
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/tfx-an-end-to-end-ml-platform-for-everyone/'},
#   {'title': 'MLIR: Accelerating AI',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'MLIR: Accelerating AI'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/VewTETEgJxw/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/VewTETEgJxw/',
#    'comments': 'https://www.oreilly.com/radar/mlir-accelerating-ai/#respond',
#    'published': 'Fri, 01 Nov 2019 00:00:23 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=23, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Chris Lattner and Tatiana Shpeisman'}],
#    'author': 'Chris Lattner and Tatiana Shpeisman',
#    'author_detail': {'name': 'Chris Lattner and Tatiana Shpeisman'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10443',
#    'guidislink': False,
#    'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/VewTETEgJxw" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/mlir-accelerating-ai/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/mlir-accelerating-ai/'},
#   {'title': 'TensorFlow Hub: The platform to share and discover pretrained models for TensorFlow',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'TensorFlow Hub: The platform to share and discover pretrained models for TensorFlow'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ej078uA5rlo/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ej078uA5rlo/',
#    'comments': 'https://www.oreilly.com/radar/tensorflow-hub-the-platform-to-share-and-discover-pretrained-models-for-tensorflow/#respond',
#    'published': 'Fri, 01 Nov 2019 00:00:22 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=22, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Mike Liang'}],
#    'author': 'Mike Liang',
#    'author_detail': {'name': 'Mike Liang'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10406',
#    'guidislink': False,
#    'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ej078uA5rlo" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/tensorflow-hub-the-platform-to-share-and-discover-pretrained-models-for-tensorflow/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/tensorflow-hub-the-platform-to-share-and-discover-pretrained-models-for-tensorflow/'},
#   {'title': 'TensorFlow Lite: ML for mobile and IoT devices',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'TensorFlow Lite: ML for mobile and IoT devices'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/5is9oo0QzJA/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/5is9oo0QzJA/',
#    'comments': 'https://www.oreilly.com/radar/tensorflow-lite-ml-for-mobile-and-iot-devices/#respond',
#    'published': 'Fri, 01 Nov 2019 00:00:00 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=305, tm_isdst=0),
#    'authors': [{'name': 'Jared Duke and Sarah Sirajuddin'}],
#    'author': 'Jared Duke and Sarah Sirajuddin',
#    'author_detail': {'name': 'Jared Duke and Sarah Sirajuddin'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10596',
#    'guidislink': False,
#    'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/5is9oo0QzJA" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/tensorflow-lite-ml-for-mobile-and-iot-devices/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/tensorflow-lite-ml-for-mobile-and-iot-devices/'},
#   {'title': 'Four short links: 31 October 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 31 October 2019'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/dcBkM4QajP4/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/dcBkM4QajP4/',
#    'comments': 'https://www.oreilly.com/radar/four-short-links-31-october-2019/#respond',
#    'published': 'Thu, 31 Oct 2019 04:01:20 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=10, tm_mday=31, tm_hour=4, tm_min=1, tm_sec=20, tm_wday=3, tm_yday=304, tm_isdst=0),
#    'authors': [{'name': 'Nat Torkington'}],
#    'author': 'Nat Torkington',
#    'author_detail': {'name': 'Nat Torkington'},
#    'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#     {'term': 'Signals', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10457',
#    'guidislink': False,
#    'summary': 'Managing Delivery Networks: A Use Case for Graph Databases &#8212; very interesting description of architecture of a routing solution. Turns out we didn&#8217;t need a graph; we needed a property graph. In short, a property graph is a graph data structure with the addition of properties (key, value pairs) which sit on the edges and [&#8230;]',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Managing Delivery Networks: A Use Case for Graph Databases &#8212; very interesting description of architecture of a routing solution. Turns out we didn&#8217;t need a graph; we needed a property graph. In short, a property graph is a graph data structure with the addition of properties (key, value pairs) which sit on the edges and [&#8230;]'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<ol>\n<li><a href="https://dev.to/fppt/managing-delivery-networks-a-use-case-for-graph-databases-2jb0">Managing Delivery Networks: A Use Case for Graph Databases</a> &#8212; very interesting description of architecture of a routing solution. <i>Turns out we didn&#8217;t need a graph; we needed a <a href="https://markorodriguez.com/2011/02/08/property-graph-algorithms/">property graph</a>. In short, a property graph is a graph data structure with the addition of properties (key, value pairs) which sit on the edges and vertices of the graph.</i></li>\n<li><a href="https://electiontechhandbook.uk/projects">GE2019 Election Tech Handbook</a> &#8212; Google Doc keeping track of the various tech projects around the UK&#8217;s 2019 general election.</li>\n<li><a href="https://trevoro.net/2019/how-to-balance-technical-debt/">How to Balance Technical Debt</a> &#8212; as no org has beautiful perfect code, every org struggles to balance feature development against paying down technical debt so they can move faster. The insight here is to quantify reliability and set expectations, so you can increase the amount of dev time when reliability falls below expectations.</li>\n<li><a href="https://github.com/bryanpkc/corkscrew">Corkscrew</a> &#8212; <i>a tool for tunneling SSH through HTTP proxies.</i></li>\n</ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/dcBkM4QajP4" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-31-october-2019/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-31-october-2019/'},
#   {'title': 'Accelerating ML at Twitter',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Accelerating ML at Twitter'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/STm6NXNjDxI/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/STm6NXNjDxI/',
#    'comments': 'https://www.oreilly.com/radar/accelerating-ml-at-twitter/#respond',
#    'published': 'Thu, 31 Oct 2019 00:00:46 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=10, tm_mday=31, tm_hour=0, tm_min=0, tm_sec=46, tm_wday=3, tm_yday=304, tm_isdst=0),
#    'authors': [{'name': 'Theodore Summe'}],
#    'author': 'Theodore Summe',
#    'author_detail': {'name': 'Theodore Summe'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10378',
#    'guidislink': False,
#    'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/STm6NXNjDxI" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/accelerating-ml-at-twitter/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/accelerating-ml-at-twitter/'},
#   {'title': 'The latest from TensorFlow',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'The latest from TensorFlow'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/fcJQ4Jm0zWM/'}],
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/fcJQ4Jm0zWM/',
#    'comments': 'https://www.oreilly.com/radar/the-latest-from-tensorflow/#respond',
#    'published': 'Thu, 31 Oct 2019 00:00:40 +0000',
#    'published_parsed': time.struct_time(tm_year=2019, tm_mon=10, tm_mday=31, tm_hour=0, tm_min=0, tm_sec=40, tm_wday=3, tm_yday=304, tm_isdst=0),
#    'authors': [{'name': 'Megan Kacholia'}],
#    'author': 'Megan Kacholia',
#    'author_detail': {'name': 'Megan Kacholia'},
#    'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#     {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#    'id': 'https://www.oreilly.com/radar/?p=10293',
#    'guidislink': False,
#    'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/fcJQ4Jm0zWM" height="1" width="1" alt=""/>'}],
#    'wfw_commentrss': 'https://www.oreilly.com/radar/the-latest-from-tensorflow/feed/',
#    'slash_comments': '0',
#    'feedburner_origlink': 'https://www.oreilly.com/radar/the-latest-from-tensorflow/'}],
#  'bozo': 0,
#  'headers': {'Content-Type': 'text/xml; charset=UTF-8',
#   'ETag': 'nREX5KrMWpJbE/UVQZanRVnO5+Y',
#   'Last-Modified': 'Wed, 06 Nov 2019 13:32:24 GMT',
#   'Content-Encoding': 'gzip',
#   'Transfer-Encoding': 'chunked',
#   'Date': 'Wed, 06 Nov 2019 14:11:20 GMT',
#   'Expires': 'Wed, 06 Nov 2019 14:11:20 GMT',
#   'Cache-Control': 'private, max-age=0',
#   'X-Content-Type-Options': 'nosniff',
#   'X-XSS-Protection': '1; mode=block',
#   'Server': 'GSE',
#   'Connection': 'close'},
#  'etag': 'nREX5KrMWpJbE/UVQZanRVnO5+Y',
#  'updated': 'Wed, 06 Nov 2019 13:32:24 GMT',
#  'updated_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=6, tm_hour=13, tm_min=32, tm_sec=24, tm_wday=2, tm_yday=310, tm_isdst=0),
#  'href': 'http://feeds.feedburner.com/oreilly/radar/atom',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'rss20',
#  'namespaces': {'content': 'http://purl.org/rss/1.0/modules/content/',
#   'wfw': 'http://wellformedweb.org/CommentAPI/',
#   'dc': 'http://purl.org/dc/elements/1.1/',
#   '': 'http://www.w3.org/2005/Atom',
#   'sy': 'http://purl.org/rss/1.0/modules/syndication/',
#   'slash': 'http://purl.org/rss/1.0/modules/slash/',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'feedburner': 'http://rssnamespace.org/feedburner/ext/1.0'}}

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
feeds.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
feeds.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %%
feeds.feed.title
# Out:
# 'Radar'

# %%
feeds.feed.subtitle
# Out:
# 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology'

# %%
feeds.feed.link
# Out:
# 'https://www.oreilly.com/radar'

# %%
feeds.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %%
feeds.entries[0].author
# Out:
# 'Nat Torkington'

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
df = pd.DataFrame(feeds.entries)
df.count()
# Out:
# author                 18
# author_detail          18
# authors                18
# comments               18
# content                18
# feedburner_origlink    18
# guidislink             18
# id                     18
# link                   18
# links                  18
# published              18
# published_parsed       18
# slash_comments         18
# summary                18
# summary_detail         18
# tags                   18
# title                  18
# title_detail           18
# wfw_commentrss         18
# dtype: int64

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
feeds.entries
# Out:
# [{'title': 'Four short links: 6 November 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Four short links: 6 November 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HApLcqKbwf8/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HApLcqKbwf8/',
#   'comments': 'https://www.oreilly.com/radar/four-short-links-6-november-2019/#respond',
#   'published': 'Wed, 06 Nov 2019 05:01:31 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=6, tm_hour=5, tm_min=1, tm_sec=31, tm_wday=2, tm_yday=310, tm_isdst=0),
#   'authors': [{'name': 'Nat Torkington'}],
#   'author': 'Nat Torkington',
#   'author_detail': {'name': 'Nat Torkington'},
#   'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10648',
#   'guidislink': False,
#   'summary': 'Things I Wish Someone Had Explained About Functional Programming (James Sinclair) &#8212; But it&#8217;s not long before things get complicated. We start with a bunch of simple functions. Easy. But the types don’t all line up. And we need to generate some side effects, too. And handle errors. And manage state. And how do you [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Things I Wish Someone Had Explained About Functional Programming (James Sinclair) &#8212; But it&#8217;s not long before things get complicated. We start with a bunch of simple functions. Easy. But the types don’t all line up. And we need to generate some side effects, too. And handle errors. And manage state. And how do you [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<ol><li><a href="https://jrsinclair.com/articles/2019/what-i-wish-someone-had-explained-about-functional-programming/">Things I Wish Someone Had Explained About Functional Programming</a> (James Sinclair) &#8212; <em>But it&#8217;s not long before things get complicated. We start with a bunch of simple functions. Easy. But the types don’t all line up. And we need to generate some side effects, too. And handle errors. And manage state. And how do you debug this? It gets tricky, quick. Functional programming has idioms and tools to solve all these challenges. But learning them is hard if nobody shows you where to look.</em></li><li><a href="https://scholar.harvard.edu/files/helpman/files/fakenews091819_combined.pdf">Electoral Competition with Fake News</a> &#8212; <em>We introduce opportunities for political candidates and their media supporters to spread fake news about the policy environment and perhaps about parties&#8217; positions into a familiar model of electoral competition. In the baseline model with full information, the parties&#8217; positions converge to those that maximize aggregate welfare. When parties can broadcast fake news to audiences that disproportionately include their partisans, policy divergence and suboptimal outcomes can result. We study a sequence of models that impose progressively tighter constraints on false reporting and characterize situations that lead to divergence and a polarized electorate.</em></li><li><a href="https://research.fb.com/publications/live-face-de-identification-in-video/">Live Face De-Identification in Video</a> &#8212; <em>We propose a method for face de-identification that enables fully automatic video modification at high frame rates. The goal is to maximally decorrelate the identity, while having the perception (pose, illumination, and expression) fixed. We achieve this by a novel feed-forward encoder-decoder network architecture that is conditioned on the high-level representation of a person’s facial image. The network is global, in the sense that it does not need to be retrained for a given video or for a given identity, and it creates natural looking image sequences with little distortion in time.</em></li><li><a href="https://www.youtube.com/watch?v=Re1MAO6jOLE">Lessons Learned from Sendmail</a> (Eric Allman) &#8212; Sendmail has a bad rap with the kids, but it&#8217;s worth listening to how it came about. If you ever invent something that has the market share that Sendmail had, then you&#8217;ll have regrets, too. This is a good opportunity to learn from Eric&#8217;s.</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/HApLcqKbwf8" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-6-november-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-6-november-2019/'},
#  {'title': 'It’s important to cultivate your organization’s collective genius',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'It’s important to cultivate your organization’s collective genius'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/wn75FBxJkk8/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/wn75FBxJkk8/',
#   'comments': 'https://www.oreilly.com/radar/its-important-to-cultivate-your-organizations-collective-genius/#respond',
#   'published': 'Tue, 05 Nov 2019 05:05:36 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=5, tm_hour=5, tm_min=5, tm_sec=36, tm_wday=1, tm_yday=309, tm_isdst=0),
#   'authors': [{'name': 'Jenn Webb'}],
#   'author': 'Jenn Webb',
#   'author_detail': {'name': 'Jenn Webb'},
#   'tags': [{'term': 'Future of the Firm', 'scheme': None, 'label': None},
#    {'term': 'Deep Dive', 'scheme': None, 'label': None},
#    {'term': "Foo Camp '19", 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10231',
#   'guidislink': False,
#   'summary': 'In this interview from O&#8217;Reilly Foo Camp 2019, Pamela Rucker, president of The Rucker Group, discusses the challenges people face when they&#8217;re entering into management roles for the first time, and how CxOs can help mitigate some of those challenges. She also talks about the future of work and how nurturing talent is going to [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'In this interview from O&#8217;Reilly Foo Camp 2019, Pamela Rucker, president of The Rucker Group, discusses the challenges people face when they&#8217;re entering into management roles for the first time, and how CxOs can help mitigate some of those challenges. She also talks about the future of work and how nurturing talent is going to [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>In this interview from O&#8217;Reilly Foo Camp 2019, Pamela Rucker, president of The Rucker Group, discusses the challenges people face when they&#8217;re entering into management roles for the first time, and how CxOs can help mitigate some of those challenges. She also talks about the future of work and how nurturing talent is going to be more important than ever.</p>\n\n\n\n<p>Highlights from the interview include:</p>\n\n\n\n<p>One of the biggest challenges new managers face is asking for help or clarification during the transition to their new management role. Rucker says the issue has more to do with company culture and leadership than with shy managers. &#8220;There are some organizations where even the most expressive people have difficulty speaking up because the culture is such that you don&#8217;t go against the grain. You don&#8217;t say anything. I remember working at a large legacy organization and we had done a great job setting the tone in the room, talking about all the things that people need to work on, how they need to be able to express their challenges, and maybe where they don&#8217;t get it. So I said, &#8216;Tell me some of the things you&#8217;re concerned about right now.&#8217; I saw on the people&#8217;s faces that they were ready to speak, and the C-level executives chose that moment to step up and say, &#8216;I really wonder who&#8217;s going to say anything.&#8217; Instantly, everyone shut down. So, I do think it&#8217;s situational. There are times when you might have people who would be brave enough to say something, but the leader has the responsibility to enable the voice. The leader has a responsibility to let people have enough power to say something in that moment that maybe they don&#8217;t agree with, and to recognize that it&#8217;s not saying anything about them as an individual leader as much as it is about the person who might need help walking that bridge.&#8221; (<a href="#t=160">02:40</a>)</p>\n\n\n\n<p>Rucker also discusses the concept of &#8220;dual paths&#8221;—not everyone is cut out to be a manager; there are other paths to fulfilling career goals, and to rewarding outstanding work. &#8220;If you think about how people transition and become more valuable over time to organizations, typically, there&#8217;s this belief that the only way for me to show additional value is for me to become a manager. &#8230; There&#8217;s an opportunity not just to progress as a manager, but maybe to go deep in your expertise, and then demonstrate how you might be well-connected in the organization or well-connected in the industry, and show how that adds value to the company&#8217;s strategic priorities. That&#8217;s just as important as being able to manage people. Talking to an organization about how they can create those types of roles is important as well because it shouldn&#8217;t be that the only way you can achieve the things you want to achieve in life is to be forced into the ability to manage people or manage projects, which may not align with your capabilities.&#8221; (<a href="#t=348">05:48</a>)</p>\n\n\n\n<p>The future of work is going to raise more issues than navigating remote work or gig economies—Rucker says leaders will need a vastly different skill set. &#8220;It&#8217;s not just about technology, but also about how to look at your staff and figure out what their capabilities are and then figure out how to attach that to your capability and really use the power of collective genius. Your competitive advantage is going to come from what you know about your customers, what you know about the products and services you offer, and what you know about your people, and then how you put those things together to come up with an incredible recipe that cannot be duplicated because you have talent equity. &#8230; A leader will need to foster an environment where they all can come together and raise up those hidden talents and then collectively put them together into som ...
#   'wfw_commentrss': 'https://www.oreilly.com/radar/its-important-to-cultivate-your-organizations-collective-genius/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/its-important-to-cultivate-your-organizations-collective-genius/'},
#  {'title': 'Four short links: 5 November 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Four short links: 5 November 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Thacsx74uOM/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Thacsx74uOM/',
#   'comments': 'https://www.oreilly.com/radar/four-short-links-5-november-2019/#respond',
#   'published': 'Tue, 05 Nov 2019 05:01:13 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=5, tm_hour=5, tm_min=1, tm_sec=13, tm_wday=1, tm_yday=309, tm_isdst=0),
#   'authors': [{'name': 'Nat Torkington'}],
#   'author': 'Nat Torkington',
#   'author_detail': {'name': 'Nat Torkington'},
#   'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10644',
#   'guidislink': False,
#   'summary': '&#8220;Nearly All&#8221; Counter-Strike Microtransactions Are Being Used for Money Laundering (Vice) &#8212; I&#8217;ve been chewing on this all week. There are a lot of unmet desires in the world, desires that are unmet because society makes them illegal to meet. If your service can be adapted to meet these desires, then it will be. And [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': '&#8220;Nearly All&#8221; Counter-Strike Microtransactions Are Being Used for Money Laundering (Vice) &#8212; I&#8217;ve been chewing on this all week. There are a lot of unmet desires in the world, desires that are unmet because society makes them illegal to meet. If your service can be adapted to meet these desires, then it will be. And [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<ol><li><a href="https://www.vice.com/en_us/article/8xw7nx/nearly-all-counter-strike-microtransactions-are-being-used-for-money-laundering">&#8220;Nearly All&#8221; Counter-Strike Microtransactions Are Being Used for Money Laundering</a> (Vice) &#8212; I&#8217;ve been chewing on this all week. There are a lot of unmet desires in the world, desires that are unmet because society makes them illegal to meet. If your service can be adapted to meet these desires, then it will be. And you&#8217;ll have a problem.</li><li><a href="https://www.whonix.org/">Whonix</a> &#8212; <em>a desktop operating system designed for advanced security and privacy. Whonix mitigates the threat of common attack vectors while maintaining usability. Online anonymity is realized via fail-safe, automatic, and desktop-wide use of the Tor network. A heavily reconfigured Debian base is run inside multiple virtual machines, providing a substantial layer of protection from malware and IP address leaks. Commonly used applications are pre-installed and safely pre-configured for immediate use. The user is not jeopardized by installing additional applications or personalizing the desktop. Whonix is under active development and is the only operating system designed to be run inside a VM and paired with Tor.</em></li><li><a href="https://ruthmalan.com/Journal/2019/20190629SlideDocTechnicalLeadershipDecisions.pdf">Technical Leadership Masterclass: Decisions</a> (Ruth Malan) &#8212; a deep dive into different frameworks and considerations when making decisions.</li><li><a href="https://twilio-labs.github.io/socless/">SOCless: Automated Security Playbooks</a> &#8212; Twilio&#8217;s open source serverless framework to execute user-defined workflows in response to alerts or scheduled events.</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/Thacsx74uOM" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-5-november-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-5-november-2019/'},
#  {'title': 'Four short links: 4 November 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Four short links: 4 November 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/JNSNstQo6Cw/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/JNSNstQo6Cw/',
#   'comments': 'https://www.oreilly.com/radar/four-short-links-4-november-2019/#respond',
#   'published': 'Mon, 04 Nov 2019 05:01:01 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=4, tm_hour=5, tm_min=1, tm_sec=1, tm_wday=0, tm_yday=308, tm_isdst=0),
#   'authors': [{'name': 'Nat Torkington'}],
#   'author': 'Nat Torkington',
#   'author_detail': {'name': 'Nat Torkington'},
#   'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10612',
#   'guidislink': False,
#   'summary': 'Beyond Bots and Trolls: Understanding Disinformation as Collaborative Work &#8212; we examine three case studies of online information operations using a sociotechnical lens that draws on CSCW theories and methods to account for the mutual shaping of technology, social structure, and human action. Through this lens, we contribute a more nuanced understanding of these operations [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Beyond Bots and Trolls: Understanding Disinformation as Collaborative Work &#8212; we examine three case studies of online information operations using a sociotechnical lens that draws on CSCW theories and methods to account for the mutual shaping of technology, social structure, and human action. Through this lens, we contribute a more nuanced understanding of these operations [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<ol><li><a href="http://faculty.washington.edu/kstarbi/StarbirdArifWilson_DisinformationasCollaborativeWork-CameraReady-Preprint.pdf">Beyond Bots and Trolls: Understanding Disinformation as Collaborative Work</a> &#8212; <em>we examine three case studies of online information operations using a sociotechnical lens that draws on CSCW theories and methods to account for the mutual shaping of technology, social structure, and human action. Through this lens, we contribute a more nuanced understanding of these operations (beyond “bots” and “trolls”) and highlight a persistent challenge for researchers, platform designers, and policy makers—distinguishing between orchestrated, explicitly coordinated, information operations and the emergent, organic behaviors of an online crowd.</em></li><li><a href="https://alf.io/">Alf.io</a> &#8212; open source ticket reservation system. Their <a href="https://alfio.netlify.com/">draft new web site</a> does a better job explaining what they do and why they&#8217;re good. (via <a href="https://news.ycombinator.com/item?id=21411267">Hacker News</a>)</li><li><a href="https://meatspacepress.com/">How to Run a City Like Amazon, and Other Fables</a> &#8212; <em>The idea behind the book is to ask what would it be like to live in a city administered using the business model of Amazon (or Apple, IKEA, Pornhub, Spotify, Tinder, Uber, and more), or a city where critical public services are delivered by these companies?</em> (via <a href="https://twitter.com/RobKitchin/status/1188783861993562113">Rob Kitchin</a>)</li><li><a href="https://quiet.github.io/quiet-js/">Quiet.js</a> &#8212; <em>a javascript binding for libquiet, a library for sending and receiving data via sound card. It can function either via speaker or cable (e.g., 3.5mm). Quiet comes included with a few transmissions profiles which can be selected for the intended use. For speaker transmission, there is a profile which transmits around the 19kHz range, which is essentially imperceptible to the human ear. Quiet uses the Web Audio functionality in order to send and receive sound. Sending data is supported by Chrome, Firefox, Safari, and Edge. Reception is supported by Chrome, Edge, and to some extent Firefox.</em></li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/JNSNstQo6Cw" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-4-november-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-4-november-2019/'},
#  {'title': 'Quantum computing’s potential is still far off, but quantum supremacy shows we’re on the right track',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Quantum computing’s potential is still far off, but quantum supremacy shows we’re on the right track'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9Fuea1TTT4E/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9Fuea1TTT4E/',
#   'comments': 'https://www.oreilly.com/radar/quantum-computings-potential-is-still-far-off-but-quantum-supremacy-shows-were-on-the-right-track/#respond',
#   'published': 'Fri, 01 Nov 2019 04:05:34 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=4, tm_min=5, tm_sec=34, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Mike Loukides'}],
#   'author': 'Mike Loukides',
#   'author_detail': {'name': 'Mike Loukides'},
#   'tags': [{'term': 'Innovation & Disruption', 'scheme': None, 'label': None},
#    {'term': 'Radar Column', 'scheme': None, 'label': None},
#    {'term': 'Commentary', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10154',
#   'guidislink': False,
#   'summary': 'One of the most exciting topics we’ve been following is the development of quantum computing. We recently learned about a major breakthrough: Google says it has achieved “quantum supremacy” with a 53-qubit computer. I will steer clear of a lengthy explanation of quantum computing, which I’m not really competent to give. Quantum supremacy itself is [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'One of the most exciting topics we’ve been following is the development of quantum computing. We recently learned about a major breakthrough: Google says it has achieved “quantum supremacy” with a 53-qubit computer. I will steer clear of a lengthy explanation of quantum computing, which I’m not really competent to give. Quantum supremacy itself is [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>One of the most exciting topics we’ve been following is the development of quantum computing. We recently learned about a major breakthrough: <a href="https://www.nature.com/articles/s41586-019-1666-5">Google says it has achieved “quantum supremacy”</a> with a 53-qubit computer.</p>\n<p>I will steer clear of a lengthy explanation of quantum computing, which I’m not really competent to give. Quantum supremacy itself is a simple concept: it means performing a computation that could not be performed on a classical computer.</p>\n<p>It’s very important to understand exactly what this means. Google performed a computation in a few minutes (3 minutes, 20 seconds to be <a href="https://www.nytimes.com/2019/10/23/technology/quantum-computing-google.html">precise</a>) that would have taken more than 10,000 years on the most powerful computers we currently have. But that’s a speedup for one specific computation, and that computation has no practical value. (<a href="https://medium.com/starts-with-a-bang/has-google-actually-achieved-quantum-supremacy-with-its-new-quantum-computer-b59d051f3d88">This explanation of the computation</a> is the best I’ve seen.) Google has verified that the result is correct—a statistical distribution that is subtly different from a Gaussian distribution.</p>\n<p>This is a major breakthrough, despite <a href="https://www.ibm.com/blogs/research/2019/10/on-quantum-supremacy/">some controversy</a> (though it’s worth pointing out that researchers <a href="https://www.quantamagazine.org/john-preskill-explains-quantum-supremacy-20191002/">John Preskill</a>—who coined the term “quantum supremacy”—and <a href="https://www.scottaaronson.com/blog/?p=4372">Scott Aaronson</a> accept Google’s understanding of quantum supremacy).</p>\n<p>It’s important to consider what this achievement does <em>not</em> mean. It does not mean that cryptography is broken, or that we can achieve general artificial intelligence, or anything of the sort. Remember, this result is about one specific computation with no practical value; it’s meaningless, except perhaps as a random number generator that obeys an odd distribution. To break current cryptographic techniques, we’ll need quantum computers with thousands of qubits. And qubits don’t stack up as easily as bytes in a memory chip.</p>\n<p>One fundamental problem with quantum computers is that the probability they’ll return an incorrect answer is always non-zero. To do meaningful computation on a quantum computer, we’ll need to develop quantum error correction. Error correction is well understood for classical computers; error correction for quantum computers isn’t. One error-corrected qubit (a “logical” qubit) may require more than a thousand physical qubits. So breaking cryptography, which may require thousands of logical qubits, will require <a href="https://www.scottaaronson.com/blog/?p=4317">millions of physical qubits</a>. Quantum computers of that scale are still a long way off.</p>\n<p>Quantum supremacy, now and in some imagined future, also doesn’t mean that digital computers become obsolete. Most of what we do on our computers—fancy graphics, email, databases, building websites, data analysis, digital signal processing—can’t be done with quantum computing. Certainly not now, and possibly never. Quantum computing is useful to speed up a relatively small number of very difficult computational problems that can’t be solved on classical computers. I suspect that quantum computers won’t be computers as such (certainly not laptops, unless you can manage a laptop that runs at temperatures close to absolute zero); they’ll be more like GPUs, specialized attachments that run certain kinds of computations.</p>\n<p>I also suspect that, for quantum computers, Thomas J. Watson’s notorious (and perhaps <a href="https://en.wikipedia.org/wiki/Thomas_J._Watson#Famous_attribution">apocryphal</a>) prediction that the total market for computers would be five, might be close to the truth ...
#   'wfw_commentrss': 'https://www.oreilly.com/radar/quantum-computings-potential-is-still-far-off-but-quantum-supremacy-shows-were-on-the-right-track/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/quantum-computings-potential-is-still-far-off-but-quantum-supremacy-shows-were-on-the-right-track/'},
#  {'title': 'Four short links: 1 November 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Four short links: 1 November 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/oInoNMRLUXw/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/oInoNMRLUXw/',
#   'comments': 'https://www.oreilly.com/radar/four-short-links-1-november-2019/#respond',
#   'published': 'Fri, 01 Nov 2019 04:01:53 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=4, tm_min=1, tm_sec=53, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Nat Torkington'}],
#   'author': 'Nat Torkington',
#   'author_detail': {'name': 'Nat Torkington'},
#   'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10586',
#   'guidislink': False,
#   'summary': 'Vortimo &#8212; software that organizes information on webpages you’ve visited. It records pages you go to, extracts data from them, and enriches the data that was extracted. It augments the pages in your browser by allowing you to tag objects as well as decorating objects it deems important. It then arranges the data in a [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Vortimo &#8212; software that organizes information on webpages you’ve visited. It records pages you go to, extracts data from them, and enriches the data that was extracted. It augments the pages in your browser by allowing you to tag objects as well as decorating objects it deems important. It then arranges the data in a [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<ol><li><a href="http://vortimo.com/beta3/">Vortimo</a> &#8212; <em>software that organizes information on webpages you’ve visited. It records pages you go to, extracts data from them, and enriches the data that was extracted. It augments the pages in your browser by allowing you to tag objects as well as decorating objects it deems important. It then arranges the data in a UI. Vortimo supports switching between cases/projects seamlessly. You can also generate PDF reports based on the aggregated information and meta information.</em></li><li><a href="http://deeppavlov.ai/">DeepPavlov</a> &#8212; <em>An open source conversational AI framework</em>.</li><li><a href="https://papers.ssrn.com/sol3/papers.cfm?abstract_id=998565">&#8216;I&#8217;ve Got Nothing to Hide&#8217; and Other Misunderstandings of Privacy</a> &#8212; 2007 paper <em>In this essay, I will explore the &#8220;nothing to hide&#8221; argument and its variants in more depth. Grappling with the &#8220;nothing to hide&#8221; argument is important because the argument reflects the sentiments of a wide percentage of the population. In popular discourse, the &#8220;nothing to hide&#8221; argument’s superficial incantations can readily be refuted. But when the argument is made in its strongest form, it is far more formidable.</em></li><li><a href="https://www.minersoc.org/wp-content/uploads/2019/05/3ICM-Michaux.pdf">Projected Battery Minerals and Metals Global Shortage</a> &#8212; eye-watering presentation, estimating the effect of predicted demand upon the supply/availability of key minerals and metals. Contains alarming statements like: <em>What is needed to replace 2016 global fleet would consume 93.3% of Global Ni Resources</em>.</li></ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/oInoNMRLUXw" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-1-november-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-1-november-2019/'},
#  {'title': 'Highlights from TensorFlow World in Santa Clara, California 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Highlights from TensorFlow World in Santa Clara, California 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/DM72RqFb2G4/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/DM72RqFb2G4/',
#   'comments': 'https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019/#respond',
#   'published': 'Fri, 01 Nov 2019 00:30:39 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=30, tm_sec=39, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Mac Slocum'}],
#   'author': 'Mac Slocum',
#   'author_detail': {'name': 'Mac Slocum'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10168',
#   'guidislink': False,
#   'summary': 'People from across the TensorFlow community came together in Santa Clara, California for TensorFlow World. Below you&#8217;ll find links to highlights from the event. Opening keynote Jeff Dean explains why Google open-sourced TensorFlow and discusses its progress. Watch &#8220;Opening keynote&#8220; Accelerating ML at Twitter Theodore Summe offers a glimpse into how Twitter employs machine learning [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'People from across the TensorFlow community came together in Santa Clara, California for TensorFlow World. Below you&#8217;ll find links to highlights from the event. Opening keynote Jeff Dean explains why Google open-sourced TensorFlow and discusses its progress. Watch &#8220;Opening keynote&#8220; Accelerating ML at Twitter Theodore Summe offers a glimpse into how Twitter employs machine learning [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>People from across the TensorFlow community came together in Santa Clara, California for <a href="https://conferences.oreilly.com/tensorflow/tf-ca">TensorFlow World</a>. Below you&#8217;ll find links to highlights from the event.</p>\n<h2>Opening keynote</h2>\n<p>Jeff Dean explains why Google open-sourced TensorFlow and discusses its progress.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tensorflow-world-2019-opening-keynote">Opening keynote</a>&#8220;</li>\n</ul>\n<h2>Accelerating ML at Twitter</h2>\n<p>Theodore Summe offers a glimpse into how Twitter employs machine learning throughout its product.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/accelerating-ml-at-twitter">Accelerating ML at Twitter</a>&#8220;</li>\n</ul>\n<h2>The latest from TensorFlow</h2>\n<p>Megan Kacholia explains how Google’s latest innovations provide an ecosystem of tools for developers, enterprises, and researchers who want to build scalable ML-powered applications.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/the-latest-from-tensorflow">The latest from TensorFlow</a>&#8220;</li>\n</ul>\n<h2>TensorFlow community announcements</h2>\n<p>Kemal El Moujahid reveals new developments for the TensorFlow community.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tensorflow-community-announcements">TensorFlow community announcements</a>&#8220;</li>\n</ul>\n<h2>TFX: An end-to-end ML platform for everyone</h2>\n<p>Konstantinos Katsiapis and Anusha Ramesh dive into the insights and approach that helped TensorFlow Extended (TFX) reach its current popularity within Alphabet.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tfx-an-end-to-end-ml-platform-for-everyone">TFX: An end-to-end ML platform for everyone</a>&#8220;</li>\n</ul>\n<h2>Personalization of Spotify Home and TensorFlow</h2>\n<p>Tony Jebara explains how Spotify improved user satisfaction by building components of the TFX ecosystem into its core ML infrastructure.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/personalization-of-spotify-home-and-tensorflow">Personalization of Spotify Home and TensorFlow</a>&#8220;</li>\n</ul>\n<h2>TensorFlow Hub: The platform to share and discover pretrained models for TensorFlow</h2>\n<p>Mike Liang discusses TensorFlow Hub, a platform where developers can share and discover pretrained models and benefit from transfer learning.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tensorflow-hub-the-platform-to-share-and-discover-pretrained-models-for-tensorflow">TensorFlow Hub: The platform to share and discover pretrained models for TensorFlow</a>&#8220;</li>\n</ul>\n<h2>“Human error”: How can we help people build models that do what they expect</h2>\n<p>Anna Roth discusses human and technical factors and suggests future directions for training machine learning models.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/human-error-how-can-we-help-people-build-models-that-do-what-they-expect">“Human error”: How can we help people build models that do what they expect</a>&#8220;</li>\n</ul>\n<h2>TensorFlow Lite: ML for mobile and IoT devices</h2>\n<p>Jared Duke and Sarah Sirajuddin explore on-device machine learning and the latest updates to TensorFlow Lite.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/tensorflow-lite-ml-for-mobile-and-iot-devices">TensorFlow Lite: ML for mobile and IoT devices</a>&#8220;</li>\n</ul>\n<h2>Sticker recommendations and AI-driven innovations on the Hike messaging platform</h2>\n<p>Ankur Narang discusses sticker recommendations with multilingual support, a key innovation driven by sophisticated natural language processing (NLP) algorithms.</p>\n<ul>\n<li>Watch &#8220;<a href="https://www.oreilly.com/radar/sticker-recommendations-and-ai-driven-innovations-on-the-hike-messaging-platform">Sticker recommendations and AI-driven innovations on the Hike messaging ...
#   'wfw_commentrss': 'https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019/'},
#  {'title': 'Sticker recommendations and AI-driven innovations on the Hike messaging platform',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Sticker recommendations and AI-driven innovations on the Hike messaging platform'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/jZNzhYYiqV4/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/jZNzhYYiqV4/',
#   'comments': 'https://www.oreilly.com/radar/sticker-recommendations-and-ai-driven-innovations-on-the-hike-messaging-platform/#respond',
#   'published': 'Fri, 01 Nov 2019 00:00:59 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=59, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Ankur Narang'}],
#   'author': 'Ankur Narang',
#   'author_detail': {'name': 'Ankur Narang'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10426',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/jZNzhYYiqV4" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/sticker-recommendations-and-ai-driven-innovations-on-the-hike-messaging-platform/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/sticker-recommendations-and-ai-driven-innovations-on-the-hike-messaging-platform/'},
#  {'title': '“Human error”: How can we help people build models that do what they expect',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': '“Human error”: How can we help people build models that do what they expect'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/IN5fi_-N3Ic/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/IN5fi_-N3Ic/',
#   'comments': 'https://www.oreilly.com/radar/human-error-how-can-we-help-people-build-models-that-do-what-they-expect/#respond',
#   'published': 'Fri, 01 Nov 2019 00:00:58 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=58, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Anna Roth'}],
#   'author': 'Anna Roth',
#   'author_detail': {'name': 'Anna Roth'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10414',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/IN5fi_-N3Ic" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/human-error-how-can-we-help-people-build-models-that-do-what-they-expect/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/human-error-how-can-we-help-people-build-models-that-do-what-they-expect/'},
#  {'title': 'Personalization of Spotify Home and TensorFlow',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Personalization of Spotify Home and TensorFlow'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/4SDP5ZmXUA4/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/4SDP5ZmXUA4/',
#   'comments': 'https://www.oreilly.com/radar/personalization-of-spotify-home-and-tensorflow/#respond',
#   'published': 'Fri, 01 Nov 2019 00:00:46 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=46, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Tony Jebara'}],
#   'author': 'Tony Jebara',
#   'author_detail': {'name': 'Tony Jebara'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10400',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/4SDP5ZmXUA4" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/personalization-of-spotify-home-and-tensorflow/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/personalization-of-spotify-home-and-tensorflow/'},
#  {'title': 'TensorFlow.js: Bringing machine learning to JavaScript',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'TensorFlow.js: Bringing machine learning to JavaScript'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/kFj_13YToRg/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/kFj_13YToRg/',
#   'comments': 'https://www.oreilly.com/radar/tensorflow-js-bringing-machine-learning-to-javascript/#respond',
#   'published': 'Fri, 01 Nov 2019 00:00:36 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=36, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Sandeep Gupta and Joseph Paul Cohen'}],
#   'author': 'Sandeep Gupta and Joseph Paul Cohen',
#   'author_detail': {'name': 'Sandeep Gupta and Joseph Paul Cohen'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10436',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/kFj_13YToRg" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/tensorflow-js-bringing-machine-learning-to-javascript/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/tensorflow-js-bringing-machine-learning-to-javascript/'},
#  {'title': 'TFX: An end-to-end ML platform for everyone',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'TFX: An end-to-end ML platform for everyone'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HDb78lkLLzo/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HDb78lkLLzo/',
#   'comments': 'https://www.oreilly.com/radar/tfx-an-end-to-end-ml-platform-for-everyone/#respond',
#   'published': 'Fri, 01 Nov 2019 00:00:29 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=29, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Konstantinos Katsiapis and Anusha Ramesh'}],
#   'author': 'Konstantinos Katsiapis and Anusha Ramesh',
#   'author_detail': {'name': 'Konstantinos Katsiapis and Anusha Ramesh'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10393',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/HDb78lkLLzo" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/tfx-an-end-to-end-ml-platform-for-everyone/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/tfx-an-end-to-end-ml-platform-for-everyone/'},
#  {'title': 'MLIR: Accelerating AI',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'MLIR: Accelerating AI'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/VewTETEgJxw/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/VewTETEgJxw/',
#   'comments': 'https://www.oreilly.com/radar/mlir-accelerating-ai/#respond',
#   'published': 'Fri, 01 Nov 2019 00:00:23 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=23, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Chris Lattner and Tatiana Shpeisman'}],
#   'author': 'Chris Lattner and Tatiana Shpeisman',
#   'author_detail': {'name': 'Chris Lattner and Tatiana Shpeisman'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10443',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/VewTETEgJxw" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/mlir-accelerating-ai/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/mlir-accelerating-ai/'},
#  {'title': 'TensorFlow Hub: The platform to share and discover pretrained models for TensorFlow',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'TensorFlow Hub: The platform to share and discover pretrained models for TensorFlow'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ej078uA5rlo/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ej078uA5rlo/',
#   'comments': 'https://www.oreilly.com/radar/tensorflow-hub-the-platform-to-share-and-discover-pretrained-models-for-tensorflow/#respond',
#   'published': 'Fri, 01 Nov 2019 00:00:22 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=22, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Mike Liang'}],
#   'author': 'Mike Liang',
#   'author_detail': {'name': 'Mike Liang'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10406',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ej078uA5rlo" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/tensorflow-hub-the-platform-to-share-and-discover-pretrained-models-for-tensorflow/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/tensorflow-hub-the-platform-to-share-and-discover-pretrained-models-for-tensorflow/'},
#  {'title': 'TensorFlow Lite: ML for mobile and IoT devices',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'TensorFlow Lite: ML for mobile and IoT devices'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/5is9oo0QzJA/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/5is9oo0QzJA/',
#   'comments': 'https://www.oreilly.com/radar/tensorflow-lite-ml-for-mobile-and-iot-devices/#respond',
#   'published': 'Fri, 01 Nov 2019 00:00:00 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=11, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=305, tm_isdst=0),
#   'authors': [{'name': 'Jared Duke and Sarah Sirajuddin'}],
#   'author': 'Jared Duke and Sarah Sirajuddin',
#   'author_detail': {'name': 'Jared Duke and Sarah Sirajuddin'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10596',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/5is9oo0QzJA" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/tensorflow-lite-ml-for-mobile-and-iot-devices/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/tensorflow-lite-ml-for-mobile-and-iot-devices/'},
#  {'title': 'Four short links: 31 October 2019',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Four short links: 31 October 2019'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/dcBkM4QajP4/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/dcBkM4QajP4/',
#   'comments': 'https://www.oreilly.com/radar/four-short-links-31-october-2019/#respond',
#   'published': 'Thu, 31 Oct 2019 04:01:20 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=10, tm_mday=31, tm_hour=4, tm_min=1, tm_sec=20, tm_wday=3, tm_yday=304, tm_isdst=0),
#   'authors': [{'name': 'Nat Torkington'}],
#   'author': 'Nat Torkington',
#   'author_detail': {'name': 'Nat Torkington'},
#   'tags': [{'term': 'Four Short Links', 'scheme': None, 'label': None},
#    {'term': 'Signals', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10457',
#   'guidislink': False,
#   'summary': 'Managing Delivery Networks: A Use Case for Graph Databases &#8212; very interesting description of architecture of a routing solution. Turns out we didn&#8217;t need a graph; we needed a property graph. In short, a property graph is a graph data structure with the addition of properties (key, value pairs) which sit on the edges and [&#8230;]',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Managing Delivery Networks: A Use Case for Graph Databases &#8212; very interesting description of architecture of a routing solution. Turns out we didn&#8217;t need a graph; we needed a property graph. In short, a property graph is a graph data structure with the addition of properties (key, value pairs) which sit on the edges and [&#8230;]'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<ol>\n<li><a href="https://dev.to/fppt/managing-delivery-networks-a-use-case-for-graph-databases-2jb0">Managing Delivery Networks: A Use Case for Graph Databases</a> &#8212; very interesting description of architecture of a routing solution. <i>Turns out we didn&#8217;t need a graph; we needed a <a href="https://markorodriguez.com/2011/02/08/property-graph-algorithms/">property graph</a>. In short, a property graph is a graph data structure with the addition of properties (key, value pairs) which sit on the edges and vertices of the graph.</i></li>\n<li><a href="https://electiontechhandbook.uk/projects">GE2019 Election Tech Handbook</a> &#8212; Google Doc keeping track of the various tech projects around the UK&#8217;s 2019 general election.</li>\n<li><a href="https://trevoro.net/2019/how-to-balance-technical-debt/">How to Balance Technical Debt</a> &#8212; as no org has beautiful perfect code, every org struggles to balance feature development against paying down technical debt so they can move faster. The insight here is to quantify reliability and set expectations, so you can increase the amount of dev time when reliability falls below expectations.</li>\n<li><a href="https://github.com/bryanpkc/corkscrew">Corkscrew</a> &#8212; <i>a tool for tunneling SSH through HTTP proxies.</i></li>\n</ol>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/dcBkM4QajP4" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/four-short-links-31-october-2019/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/four-short-links-31-october-2019/'},
#  {'title': 'Accelerating ML at Twitter',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Accelerating ML at Twitter'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/STm6NXNjDxI/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/STm6NXNjDxI/',
#   'comments': 'https://www.oreilly.com/radar/accelerating-ml-at-twitter/#respond',
#   'published': 'Thu, 31 Oct 2019 00:00:46 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=10, tm_mday=31, tm_hour=0, tm_min=0, tm_sec=46, tm_wday=3, tm_yday=304, tm_isdst=0),
#   'authors': [{'name': 'Theodore Summe'}],
#   'author': 'Theodore Summe',
#   'author_detail': {'name': 'Theodore Summe'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10378',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/STm6NXNjDxI" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/accelerating-ml-at-twitter/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/accelerating-ml-at-twitter/'},
#  {'title': 'The latest from TensorFlow',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'The latest from TensorFlow'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/fcJQ4Jm0zWM/'}],
#   'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/fcJQ4Jm0zWM/',
#   'comments': 'https://www.oreilly.com/radar/the-latest-from-tensorflow/#respond',
#   'published': 'Thu, 31 Oct 2019 00:00:40 +0000',
#   'published_parsed': time.struct_time(tm_year=2019, tm_mon=10, tm_mday=31, tm_hour=0, tm_min=0, tm_sec=40, tm_wday=3, tm_yday=304, tm_isdst=0),
#   'authors': [{'name': 'Megan Kacholia'}],
#   'author': 'Megan Kacholia',
#   'author_detail': {'name': 'Megan Kacholia'},
#   'tags': [{'term': 'AI & ML', 'scheme': None, 'label': None},
#    {'term': 'TensorFlow World 2019', 'scheme': None, 'label': None}],
#   'id': 'https://www.oreilly.com/radar/?p=10293',
#   'guidislink': False,
#   'summary': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'This is a keynote from TensorFlow World in Santa Clara, California 2019. See more keynotes from this event.'},
#   'content': [{'type': 'text/html',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': '<p>This is a keynote from TensorFlow World in Santa Clara, California 2019.</p>\n\n<p><a href="https://www.oreilly.com/radar/highlights-from-tensorflow-world-2019">See more keynotes from this event</a>.</p>\n<img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/fcJQ4Jm0zWM" height="1" width="1" alt=""/>'}],
#   'wfw_commentrss': 'https://www.oreilly.com/radar/the-latest-from-tensorflow/feed/',
#   'slash_comments': '0',
#   'feedburner_origlink': 'https://www.oreilly.com/radar/the-latest-from-tensorflow/'}]

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
feeds.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
titles = [feeds.entries[i].title for i in range(len(feeds.entries))]

# %%
all_titles = len(titles)
links = len(list(filter(lambda x: x.startswith("Four short links"), titles)))
perc = round(links*100 / all_titles, 0)

print("The occurrence of 'Four short links'",perc, "percent")
# Out:
# The occurrence of 'Four short links' 28.0 percent

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(feeds.entries)
df.head(5)
# Out:
#            author               author_detail                       authors  \
# 0  Nat Torkington  {'name': 'Nat Torkington'}  [{'name': 'Nat Torkington'}]
# 1       Jenn Webb       {'name': 'Jenn Webb'}       [{'name': 'Jenn Webb'}]
# 2  Nat Torkington  {'name': 'Nat Torkington'}  [{'name': 'Nat Torkington'}]
# 3  Nat Torkington  {'name': 'Nat Torkington'}  [{'name': 'Nat Torkington'}]
# 4   Mike Loukides   {'name': 'Mike Loukides'}   [{'name': 'Mike Loukides'}]
#
#                                             comments  \
# 0  https://www.oreilly.com/radar/four-short-links...
# 1  https://www.oreilly.com/radar/its-important-to...
# 2  https://www.oreilly.com/radar/four-short-links...
# 3  https://www.oreilly.com/radar/four-short-links...
# 4  https://www.oreilly.com/radar/quantum-computin...
#
#                                              content  \
# 0  [{'type': 'text/html', 'language': None, 'base...
# 1  [{'type': 'text/html', 'language': None, 'base...
# 2  [{'type': 'text/html', 'language': None, 'base...
# 3  [{'type': 'text/html', 'language': None, 'base...
# 4  [{'type': 'text/html', 'language': None, 'base...
#
#                                  feedburner_origlink  guidislink  \
# 0  https://www.oreilly.com/radar/four-short-links...       False
# 1  https://www.oreilly.com/radar/its-important-to...       False
# 2  https://www.oreilly.com/radar/four-short-links...       False
# 3  https://www.oreilly.com/radar/four-short-links...       False
# 4  https://www.oreilly.com/radar/quantum-computin...       False
#
#                                        id  \
# 0  https://www.oreilly.com/radar/?p=10648
# 1  https://www.oreilly.com/radar/?p=10231
# 2  https://www.oreilly.com/radar/?p=10644
# 3  https://www.oreilly.com/radar/?p=10612
# 4  https://www.oreilly.com/radar/?p=10154
#
#                                                 link  \
# 0  http://feedproxy.google.com/~r/oreilly/radar/a...
# 1  http://feedproxy.google.com/~r/oreilly/radar/a...
# 2  http://feedproxy.google.com/~r/oreilly/radar/a...
# 3  http://feedproxy.google.com/~r/oreilly/radar/a...
# 4  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                          published                    published_parsed  \
# 0  Wed, 06 Nov 2019 05:01:31 +0000  (2019, 11, 6, 5, 1, 31, 2, 310, 0)
# 1  Tue, 05 Nov 2019 05:05:36 +0000  (2019, 11, 5, 5, 5, 36, 1, 309, 0)
# 2  Tue, 05 Nov 2019 05:01:13 +0000  (2019, 11, 5, 5, 1, 13, 1, 309, 0)
# 3  Mon, 04 Nov 2019 05:01:01 +0000   (2019, 11, 4, 5, 1, 1, 0, 308, 0)
# 4  Fri, 01 Nov 2019 04:05:34 +0000  (2019, 11, 1, 4, 5, 34, 4, 305, 0)
#
#   slash_comments                                            summary  \
# 0              0  Things I Wish Someone Had Explained About Func...
# 1              0  In this interview from O&#8217;Reilly Foo Camp...
# 2              0  &#8220;Nearly All&#8221; Counter-Strike Microt...
# 3              0  Beyond Bots and Trolls: Understanding Disinfor...
# 4              0  One of the most exciting topics we’ve been fol...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': None, 'base'...
# 1  {'type': 'text/html', 'language': None, 'base'...
# 2  {'type': 'text/html', 'language': None, 'base'...
# 3  {'type': 'text/html', 'language': None, 'base'...
# 4  {'type': 'text/html', 'language': None, 'base'...
#
#                                                 tags  \
# 0  [{'term': 'Four Short Links', 'scheme': None, ...
# 1  [{'term': 'Future of the Firm', 'scheme': None...
# 2  [{'term': 'Four Short Links', 'scheme': None, ...
# 3  [{'term': 'Four Short Links', 'scheme': None, ...
# 4  [{'term': 'Innovation & Disruption', 'scheme':...
#
#                                                title  \
# 0                  Four short links: 6 November 2019
# 1  It’s important to cultivate your organization’...
# 2                  Four short links: 5 November 2019
# 3                  Four short links: 4 November 2019
# 4  Quantum computing’s potential is still far off...
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
#
#                                       wfw_commentrss
# 0  https://www.oreilly.com/radar/four-short-links...
# 1  https://www.oreilly.com/radar/its-important-to...
# 2  https://www.oreilly.com/radar/four-short-links...
# 3  https://www.oreilly.com/radar/four-short-links...
# 4  https://www.oreilly.com/radar/quantum-computin...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#                                       author  entries
# 10                            Nat Torkington        5
# 0                               Ankur Narang        1
# 1                                  Anna Roth        1
# 2        Chris Lattner and Tatiana Shpeisman        1
# 3            Jared Duke and Sarah Sirajuddin        1
# 4                                  Jenn Webb        1
# 5   Konstantinos Katsiapis and Anusha Ramesh        1
# 6                                 Mac Slocum        1
# 7                             Megan Kacholia        1
# 8                                 Mike Liang        1
# 9                              Mike Loukides        1
# 11       Sandeep Gupta and Joseph Paul Cohen        1
# 12                            Theodore Summe        1
# 13                               Tony Jebara        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
length = lambda x: len(x)

lenght_of_entry_title = list(map(length, df.title))
df['lenght_of_entry_title'] = lenght_of_entry_title

lenght_1 = df[['author', 'lenght_of_entry_title']].copy()
lenght_1.sort_values(['lenght_of_entry_title'], ascending=False)
# Out:
#                                       author  lenght_of_entry_title
# 4                              Mike Loukides                    100
# 13                                Mike Liang                     83
# 7                               Ankur Narang                     80
# 8                                  Anna Roth                     75
# 1                                  Jenn Webb                     65
# 6                                 Mac Slocum                     64
# 10       Sandeep Gupta and Joseph Paul Cohen                     54
# 9                                Tony Jebara                     46
# 14           Jared Duke and Sarah Sirajuddin                     46
# 11  Konstantinos Katsiapis and Anusha Ramesh                     43
# 15                            Nat Torkington                     33
# 0                             Nat Torkington                     33
# 5                             Nat Torkington                     33
# 3                             Nat Torkington                     33
# 2                             Nat Torkington                     33
# 16                            Theodore Summe                     26
# 17                            Megan Kacholia                     26
# 12       Chris Lattner and Tatiana Shpeisman                     21

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
#machine_learning = [feeds.entries[i].summary for i in range(len(feeds.entries))]

# %%
machine_learning_list = [i for i in df["title"] if "machine learning" in i]
machine_learning_list
# Out:
# ['TensorFlow.js: Bringing machine learning to JavaScript']
