# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
response = feedparser.parse(url)
response
# Out:
# {'feed': {'title': 'Radar',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Radar'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.oreilly.com/radar'},
#    {'rel': 'self',
#     'type': 'application/rss+xml',
#     'href': 'http://feeds.feedburner.com/oreilly/radar/atom'},
#    {'rel': 'hub',
#     'href': 'http://pubsubhubbub.appspot.com/',
#     'type': 'text/html'}],
#   'link': 'https://www.oreilly.com/radar',
#   'subtitle': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology'},
#   'updated': 'Wed, 06 Nov 2019 18:47:10 +0000',
# ...

# %%
type(response)
# Out:
# 12

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
response.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
response.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, and link.

# %%
title = response.feed.title
print(title)

subtitle = response.feed.subtitle
print(subtitle)

link = response.feed.link
print(link)
# Out:
# Radar
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(response.entries)
# Out:
# 18

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
response.entries[3].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
entry_titles = [response.entries[i].title for i in range(0,len(response.entries))]
entry_titles
# Out:
# ['Highlights from the O’Reilly Velocity Conference in Berlin 2019',
#  'Highlights from the O’Reilly Software Architecture Conference in Berlin 2019',
#  'Modern machine learning architectures: Data and hardware and platform, oh my',
#  'The new norms of cloud native',
#  'Observability: Understanding production through your customers’ eyes',
#  'Secure reliable systems',
#  'My love letter to computer science is very short and I also forgot to mail it',
#  'Everything is a little bit broken; or, The illusion of control',
#  'Four short links: 6 November 2019',
#  'It’s important to cultivate your organization’s collective genius',
#  'Four short links: 5 November 2019',
#  'Four short links: 4 November 2019',
#  'Quantum computing’s potential is still far off, but quantum supremacy shows we’re on the right track',
#  'Four short links: 1 November 2019',
#  'Highlights from TensorFlow World in Santa Clara, California 2019',
# ...

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
four_short_links = [i for i in entry_titles if i[:16] == "Four short links"]
four_short_links

percentage = len(four_short_links)/len(entry_titles) * 100 
percentage
# Out:
# 22.22222222222222

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df =pd.DataFrame(response.entries)
df
# Out:
#                                                 title  \
# 0   Highlights from the O’Reilly Velocity Conferen...
# 1   Highlights from the O’Reilly Software Architec...
# 2   Modern machine learning architectures: Data an...
# 3                       The new norms of cloud native
# 4   Observability: Understanding production throug...
# 5                             Secure reliable systems
# 6   My love letter to computer science is very sho...
# 7   Everything is a little bit broken; or, The ill...
# 8                   Four short links: 6 November 2019
# 9   It’s important to cultivate your organization’...
# 10                  Four short links: 5 November 2019
# 11                  Four short links: 4 November 2019
# 12  Quantum computing’s potential is still far off...
# 13                  Four short links: 1 November 2019
# 14  Highlights from TensorFlow World in Santa Clar...
# 15  Sticker recommendations and AI-driven innovati...
# ...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#               author  entries
# 11    Nat Torkington        4
# 9         Mac Slocum        3
# 0          Ana Oprea        1
# 1       Ankur Narang        1
# 2          Anna Roth        1
# 3      Brian Sletten        1
# 4        Cheryl Hung        1
# 5      Christine Yen        1
# 6   Heidi Waterhouse        1
# 7      James Mickens        1
# 8          Jenn Webb        1
# 10     Mike Loukides        1
# 12       Tony Jebara        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
#new column with lenght
df["title length"] = [len(i) for i in df["title"]]

#sort values
df[["title","author","title length"]].sort_values("title length", ascending=False)


#df["title length"] = df.apply(lambda x: len(x['title']), axis=1)
# Out:
#                                                 title            author  \
# 12  Quantum computing’s potential is still far off...     Mike Loukides
# 15  Sticker recommendations and AI-driven innovati...      Ankur Narang
# 6   My love letter to computer science is very sho...     James Mickens
# 1   Highlights from the O’Reilly Software Architec...        Mac Slocum
# 2   Modern machine learning architectures: Data an...     Brian Sletten
# 16  “Human error”: How can we help people build mo...         Anna Roth
# 4   Observability: Understanding production throug...     Christine Yen
# 9   It’s important to cultivate your organization’...         Jenn Webb
# 14  Highlights from TensorFlow World in Santa Clar...        Mac Slocum
# 0   Highlights from the O’Reilly Velocity Conferen...        Mac Slocum
# 7   Everything is a little bit broken; or, The ill...  Heidi Waterhouse
# 17     Personalization of Spotify Home and TensorFlow       Tony Jebara
# ...

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
[i for i in df["title"] if "machine learning" in i]
# Out:
# ['Modern machine learning architectures: Data and hardware and platform, oh my']
